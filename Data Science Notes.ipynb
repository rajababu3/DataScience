# %% [markdown]
# #### Practice Tableau

# %% [markdown]
# ##### Q: We have data set for a company and we want to find we made the highest sale based on regions and give bonus?

# %%
from IPython.display import Image, display
display(Image(filename='Visualisation/Annual Bonus Analysis.png'))

# %% [markdown]
# #### Above is Graphical representation of Data set and we can clearly show that Matthew from central, Susan from East and James from west are employees to get bonus

# %% [markdown]
# ## Data Mining
#
# Generally, data mining (sometimes called data or knowledge discovery) is the process of analyzing data from different perspectives and summarizing it into useful information - information that can be used to increase revenue, cuts costs, or both.<br>Technically, data mining is the process of finding correlations or patterns among dozens of fields in large relational databases.

# %% [markdown]
# <h2> Q: </h2>I have bank data which is located in 3 regions <b> Spain, France and Germany </b></br>
# I have to perform AB Test and given reason to bank why customers are leaving their bank

# %% [markdown]
# ### AB Testing:
# It is a method to compare two types of things and check which performs better.
# I have used chi-squred test to validate my results.Link for chi-squared test<br>
# http://www.evanmiller.org/ab-testing/chi-squared.html

# %% [markdown]
# ## Modelling

# %% [markdown]
# #### Types of variables
# <ol>
# <li> Categorical </li>
#     <ul>
#         <li>Nominal: Eg: Male, Female or Colors </li>
#         <li>Categorical: Eg: Small, Medium or Large </li>
#     </ul>
# <li>Numeric</li>
#     <ul>
#         <li>Discrete: Eg: whole numbers(not fractions) </li>
#         <li>Continuous: Eg: Can be Fraction(Age, Height) </li>
#     </ul>
# </ol>
