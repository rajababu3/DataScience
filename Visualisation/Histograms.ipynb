# %%
#Standard
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
#Stats
from scipy import stats

# %%
#Plotting
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  7.,   5.,  20.,  22.,  18.,  13.,   4.,   9.,   1.,   1.]),
#  array([-2.09530808, -1.53305164, -0.9707952 , -0.40853876,  0.15371768,
#          0.71597412,  1.27823056,  1.840487  ,  2.40274343,  2.96499987,
#          3.52725631]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2)
# Out:
# (array([  3.,   2.,   5.,  14.,  10.,  17.,  16.,   4.,   8.,   1.]),
#  array([-2.77930338, -2.25689016, -1.73447693, -1.2120637 , -0.68965047,
#         -0.16723724,  0.35517599,  0.87758922,  1.40000244,  1.92241567,
#          2.4448289 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed=True, bins=20, alpha=0.5, color='indianred')
plt.hist(dataset2, normed=True, bins=20, alpha=0.5)
# Out:
# (array([ 0.14356451,  0.        ,  0.04785484,  0.04785484,  0.14356451,
#          0.09570967,  0.33498386,  0.33498386,  0.28712902,  0.19141935,
#          0.33498386,  0.47854837,  0.3828387 ,  0.3828387 ,  0.09570967,
#          0.09570967,  0.19141935,  0.19141935,  0.        ,  0.04785484]),
#  array([-2.77930338, -2.51809677, -2.25689016, -1.99568354, -1.73447693,
#         -1.47327031, -1.2120637 , -0.95085708, -0.68965047, -0.42844386,
#         -0.16723724,  0.09396937,  0.35517599,  0.6163826 ,  0.87758922,
#          1.13879583,  1.40000244,  1.66120906,  1.92241567,  2.18362229,
#          2.4448289 ]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1, data2)

# %%
sns.jointplot(data1)
